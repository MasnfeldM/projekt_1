# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_regression
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
import pycaret
from pycaret.regression import *

import matplotlib.pyplot as plt
import plotly.express as px
import tensorflow as tf
from sklearn.base import BaseEstimator, RegressorMixin
import xgboost as xgb
import plotly.graph_objects as go

# %% [markdown]
# # Preprocessing

# %%
# načtení datasetu z CSV souboru
data = pd.read_csv('procraft_corrosion_kbely_data_v02.csv')
dataframe = pd.DataFrame(data)
datetime = dataframe['Datetime']
dataframe = dataframe.drop(columns=['corrosion', 'Datetime'])
target = dataframe['corrosion_diff']



# Vyhlazení dat pomocí klouzavého průměru
dataframe = dataframe.rolling(window=10).mean()



# Normalizace dat
scaler = MinMaxScaler(feature_range=(0, 1))
dataframe = pd.DataFrame(scaler.fit_transform(dataframe), columns=dataframe.columns)
dataframe.fillna(0, inplace=True)

# Rozdělení dat na roční období pro trénování a zbytek pro ověření modelu
one_year = datetime[8761]
one_year_data = dataframe[:8762]

# %% [markdown]
# # Vlastní model

# %%
from pycaret.regression import add_metric
from sklearn.base import BaseEstimator, RegressorMixin
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

class LSTMRegressor(BaseEstimator, RegressorMixin):
    def __init__(self, input_shape=(10, 1), units=50, epochs=10, batch_size=32, learning_rate=0.001):
        self.input_shape = input_shape
        self.units = units
        self.epochs = epochs
        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.model = None

    def build_model(self):
        model = Sequential()
        model.add(LSTM(self.units, input_shape=self.input_shape))
        model.add(Dense(1))
        model.compile(optimizer=Adam(learning_rate=self.learning_rate), loss='mse')
        return model

    def fit(self, X, y):
        X = X.values.reshape((X.shape[0], X.shape[1], 1))  
        self.model = self.build_model()
        self.model.fit(X, y, epochs=self.epochs, batch_size=self.batch_size, verbose=0)
        return self

    def predict(self, X):
        X = X.values.reshape((X.shape[0], X.shape[1], 1))  
        return self.model.predict(X).flatten()

# %% [markdown]
# # Porovnávání modelů

# %%
exp = RegressionExperiment()
exp.setup(data=one_year_data, target='corrosion_diff')
models = exp.models().index.tolist()
models.append(LSTMRegressor())
best_model = exp.compare_models(include = models, sort='R2', turbo=False)
# Out:
# <style type="text/css">
# #T_a1c67_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a1c67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1c67_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a1c67_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1c67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1c67_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a1c67_row0_col1" class="data row0 col1" >1497</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a1c67_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a1c67_row1_col1" class="data row1 col1" >corrosion_diff</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a1c67_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a1c67_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a1c67_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a1c67_row3_col1" class="data row3 col1" >(8762, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a1c67_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a1c67_row4_col1" class="data row4 col1" >(8762, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a1c67_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a1c67_row5_col1" class="data row5 col1" >(6133, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a1c67_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a1c67_row6_col1" class="data row6 col1" >(2629, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a1c67_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_a1c67_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a1c67_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_a1c67_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a1c67_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_a1c67_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a1c67_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_a1c67_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a1c67_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_a1c67_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a1c67_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_a1c67_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a1c67_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_a1c67_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a1c67_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_a1c67_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a1c67_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_a1c67_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a1c67_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_a1c67_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a1c67_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_a1c67_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a1c67_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a1c67_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_a1c67_row18_col1" class="data row18 col1" >2da5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_cffc0 th {
#   text-align: left;
# }
# #T_cffc0_row0_col0, #T_cffc0_row1_col0, #T_cffc0_row1_col1, #T_cffc0_row1_col2, #T_cffc0_row1_col3, #T_cffc0_row1_col4, #T_cffc0_row1_col5, #T_cffc0_row1_col6, #T_cffc0_row2_col0, #T_cffc0_row2_col1, #T_cffc0_row2_col2, #T_cffc0_row2_col3, #T_cffc0_row2_col4, #T_cffc0_row2_col5, #T_cffc0_row2_col6, #T_cffc0_row3_col0, #T_cffc0_row3_col1, #T_cffc0_row3_col2, #T_cffc0_row3_col3, #T_cffc0_row3_col4, #T_cffc0_row3_col5, #T_cffc0_row3_col6, #T_cffc0_row4_col0, #T_cffc0_row4_col1, #T_cffc0_row4_col2, #T_cffc0_row4_col3, #T_cffc0_row4_col4, #T_cffc0_row4_col5, #T_cffc0_row4_col6, #T_cffc0_row5_col0, #T_cffc0_row5_col1, #T_cffc0_row5_col2, #T_cffc0_row5_col3, #T_cffc0_row5_col4, #T_cffc0_row5_col5, #T_cffc0_row5_col6, #T_cffc0_row6_col0, #T_cffc0_row6_col1, #T_cffc0_row6_col2, #T_cffc0_row6_col3, #T_cffc0_row6_col4, #T_cffc0_row6_col5, #T_cffc0_row6_col6, #T_cffc0_row7_col0, #T_cffc0_row7_col1, #T_cffc0_row7_col2, #T_cffc0_row7_col3, #T_cffc0_row7_col4, #T_cffc0_row7_col5, #T_cffc0_row7_col6, #T_cffc0_row8_col0, #T_cffc0_row8_col1, #T_cffc0_row8_col2, #T_cffc0_row8_col3, #T_cffc0_row8_col4, #T_cffc0_row8_col5, #T_cffc0_row8_col6, #T_cffc0_row9_col0, #T_cffc0_row9_col1, #T_cffc0_row9_col2, #T_cffc0_row9_col3, #T_cffc0_row9_col4, #T_cffc0_row9_col5, #T_cffc0_row9_col6, #T_cffc0_row10_col0, #T_cffc0_row10_col1, #T_cffc0_row10_col2, #T_cffc0_row10_col3, #T_cffc0_row10_col4, #T_cffc0_row10_col5, #T_cffc0_row10_col6, #T_cffc0_row11_col0, #T_cffc0_row11_col1, #T_cffc0_row11_col2, #T_cffc0_row11_col3, #T_cffc0_row11_col4, #T_cffc0_row11_col5, #T_cffc0_row11_col6, #T_cffc0_row12_col0, #T_cffc0_row12_col1, #T_cffc0_row12_col2, #T_cffc0_row12_col3, #T_cffc0_row12_col4, #T_cffc0_row12_col5, #T_cffc0_row12_col6, #T_cffc0_row13_col0, #T_cffc0_row13_col1, #T_cffc0_row13_col2, #T_cffc0_row13_col3, #T_cffc0_row13_col4, #T_cffc0_row13_col5, #T_cffc0_row13_col6, #T_cffc0_row14_col0, #T_cffc0_row14_col1, #T_cffc0_row14_col2, #T_cffc0_row14_col3, #T_cffc0_row14_col4, #T_cffc0_row14_col5, #T_cffc0_row14_col6, #T_cffc0_row15_col0, #T_cffc0_row15_col1, #T_cffc0_row15_col2, #T_cffc0_row15_col3, #T_cffc0_row15_col4, #T_cffc0_row15_col5, #T_cffc0_row15_col6, #T_cffc0_row16_col0, #T_cffc0_row16_col1, #T_cffc0_row16_col2, #T_cffc0_row16_col3, #T_cffc0_row16_col4, #T_cffc0_row16_col5, #T_cffc0_row16_col6, #T_cffc0_row17_col0, #T_cffc0_row17_col1, #T_cffc0_row17_col2, #T_cffc0_row17_col3, #T_cffc0_row17_col4, #T_cffc0_row17_col5, #T_cffc0_row17_col6, #T_cffc0_row18_col0, #T_cffc0_row18_col1, #T_cffc0_row18_col2, #T_cffc0_row18_col3, #T_cffc0_row18_col4, #T_cffc0_row18_col5, #T_cffc0_row18_col6, #T_cffc0_row19_col0, #T_cffc0_row19_col1, #T_cffc0_row19_col2, #T_cffc0_row19_col3, #T_cffc0_row19_col4, #T_cffc0_row19_col5, #T_cffc0_row19_col6, #T_cffc0_row20_col0, #T_cffc0_row20_col1, #T_cffc0_row20_col2, #T_cffc0_row20_col3, #T_cffc0_row20_col4, #T_cffc0_row20_col5, #T_cffc0_row20_col6, #T_cffc0_row21_col0, #T_cffc0_row21_col1, #T_cffc0_row21_col2, #T_cffc0_row21_col3, #T_cffc0_row21_col4, #T_cffc0_row21_col5, #T_cffc0_row21_col6, #T_cffc0_row22_col0, #T_cffc0_row22_col1, #T_cffc0_row22_col2, #T_cffc0_row22_col3, #T_cffc0_row22_col4, #T_cffc0_row22_col5, #T_cffc0_row22_col6, #T_cffc0_row23_col0, #T_cffc0_row23_col1, #T_cffc0_row23_col2, #T_cffc0_row23_col3, #T_cffc0_row23_col4, #T_cffc0_row23_col5, #T_cffc0_row23_col6, #T_cffc0_row24_col0, #T_cffc0_row24_col1, #T_cffc0_row24_col2, #T_cffc0_row24_col3, #T_cffc0_row24_col4, #T_cffc0_row24_col5, #T_cffc0_row24_col6 {
#   text-align: left;
# }
# #T_cffc0_row0_col1, #T_cffc0_row0_col2, #T_cffc0_row0_col3, #T_cffc0_row0_col4, #T_cffc0_row0_col5, #T_cffc0_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cffc0_row0_col7, #T_cffc0_row1_col7, #T_cffc0_row2_col7, #T_cffc0_row3_col7, #T_cffc0_row4_col7, #T_cffc0_row5_col7, #T_cffc0_row6_col7, #T_cffc0_row7_col7, #T_cffc0_row8_col7, #T_cffc0_row9_col7, #T_cffc0_row10_col7, #T_cffc0_row11_col7, #T_cffc0_row12_col7, #T_cffc0_row13_col7, #T_cffc0_row14_col7, #T_cffc0_row15_col7, #T_cffc0_row16_col7, #T_cffc0_row17_col7, #T_cffc0_row18_col7, #T_cffc0_row19_col7, #T_cffc0_row20_col7, #T_cffc0_row21_col7, #T_cffc0_row23_col7, #T_cffc0_row24_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cffc0_row22_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cffc0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cffc0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cffc0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cffc0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cffc0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cffc0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cffc0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cffc0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_cffc0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cffc0_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_cffc0_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_cffc0_row0_col1" class="data row0 col1" >0.0262</td>
#       <td id="T_cffc0_row0_col2" class="data row0 col2" >0.0020</td>
#       <td id="T_cffc0_row0_col3" class="data row0 col3" >0.0447</td>
#       <td id="T_cffc0_row0_col4" class="data row0 col4" >0.8765</td>
#       <td id="T_cffc0_row0_col5" class="data row0 col5" >0.0389</td>
#       <td id="T_cffc0_row0_col6" class="data row0 col6" >0.2611</td>
#       <td id="T_cffc0_row0_col7" class="data row0 col7" >0.2190</td>
#     </tr>
#     <tr>
#       <th id="T_cffc0_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_cffc0_row1_col0" class="data row1 col0" >K Neighbors Regressor</td>
#       <td id="T_cffc0_row1_col1" class="data row1 col1" >0.0269</td>
#       <td id="T_cffc0_row1_col2" class="data row1 col2" >0.0028</td>
#       <td id="T_cffc0_row1_col3" class="data row1 col3" >0.0530</td>
#       <td id="T_cffc0_row1_col4" class="data row1 col4" >0.8277</td>
#       <td id="T_cffc0_row1_col5" class="data row1 col5" >0.0467</td>
#       <td id="T_cffc0_row1_col6" class="data row1 col6" >0.2865</td>
#       <td id="T_cffc0_row1_col7" class="data row1 col7" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_cffc0_level0_row2" class="row_heading level0 row2" >17</th>
#       <td id="T_cffc0_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_cffc0_row2_col1" class="data row2 col1" >0.0348</td>
#       <td id="T_cffc0_row2_col2" class="data row2 col2" >0.0031</td>
#       <td id="T_cffc0_row2_col3" class="data row2 col3" >0.0557</td>
#       <td id="T_cffc0_row2_col4" class="data row2 col4" >0.8102</td>
#       <td id="T_cffc0_row2_col5" class="data row2 col5" >0.0479</td>
#       <td id="T_cffc0_row2_col6" class="data row2 col6" >0.3560</td>
#       <td id="T_cffc0_row2_col7" class="data row2 col7" >4.5830</td>
#     </tr>
#     <tr>
#       <th id="T_cffc0_level0_row3" class="row_heading level0 row3" >22</th>
#       <td id="T_cffc0_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_cffc0_row3_col1" class="data row3 col1" >0.0351</td>
#       <td id="T_cffc0_row3_col2" class="data row3 col2" >0.0031</td>
#       <td id="T_cffc0_row3_col3" class="data row3 col3" >0.0559</td>
#       <td id="T_cffc0_row3_col4" class="data row3 col4" >0.8092</td>
#       <td id="T_cffc0_row3_col5" class="data row3 col5" >0.0486</td>
#       <td id="T_cffc0_row3_col6" class="data row3 col6" >0.3221</td>
#       <td id="T_cffc0_row3_col7" class="data row3 col7" >10.6140</td>
#     </tr>
#     <tr>
#       <th id="T_cffc0_level0_row4" class="row_heading level0 row4" >23</th>
#       <td id="T_cffc0_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cffc0_row4

# %% [markdown]
# # Učení

# %%
best_model = exp.create_model(best_model[0])
best_model = exp.tune_model(best_model, n_iter=10, optimize='R2')
best_model = exp.finalize_model(best_model)
# Out:
# <style type="text/css">
# #T_a3556_row10_col0, #T_a3556_row10_col1, #T_a3556_row10_col2, #T_a3556_row10_col3, #T_a3556_row10_col4, #T_a3556_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_a3556">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3556_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a3556_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a3556_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a3556_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a3556_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_a3556_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3556_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3556_row0_col0" class="data row0 col0" >0.0248</td>
#       <td id="T_a3556_row0_col1" class="data row0 col1" >0.0063</td>
#       <td id="T_a3556_row0_col2" class="data row0 col2" >0.0791</td>
#       <td id="T_a3556_row0_col3" class="data row0 col3" >0.6516</td>
#       <td id="T_a3556_row0_col4" class="data row0 col4" >0.0667</td>
#       <td id="T_a3556_row0_col5" class="data row0 col5" >0.2892</td>
#     </tr>
#     <tr>
#       <th id="T_a3556_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3556_row1_col0" class="data row1 col0" >0.0264</td>
#       <td id="T_a3556_row1_col1" class="data row1 col1" >0.0059</td>
#       <td id="T_a3556_row1_col2" class="data row1 col2" >0.0770</td>
#       <td id="T_a3556_row1_col3" class="data row1 col3" >0.6933</td>
#       <td id="T_a3556_row1_col4" class="data row1 col4" >0.0676</td>
#       <td id="T_a3556_row1_col5" class="data row1 col5" >0.2478</td>
#     </tr>
#     <tr>
#       <th id="T_a3556_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3556_row2_col0" class="data row2 col0" >0.0225</td>
#       <td id="T_a3556_row2_col1" class="data row2 col1" >0.0046</td>
#       <td id="T_a3556_row2_col2" class="data row2 col2" >0.0680</td>
#       <td id="T_a3556_row2_col3" class="data row2 col3" >0.7355</td>
#       <td id="T_a3556_row2_col4" class="data row2 col4" >0.0602</td>
#       <td id="T_a3556_row2_col5" class="data row2 col5" >0.2585</td>
#     </tr>
#     <tr>
#       <th id="T_a3556_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3556_row3_col0" class="data row3 col0" >0.0307</td>
#       <td id="T_a3556_row3_col1" class="data row3 col1" >0.0063</td>
#       <td id="T_a3556_row3_col2" class="data row3 col2" >0.0791</td>
#       <td id="T_a3556_row3_col3" class="data row3 col3" >0.6521</td>
#       <td id="T_a3556_row3_col4" class="data row3 col4" >0.0705</td>
#       <td id="T_a3556_row3_col5" class="data row3 col5" >0.3465</td>
#     </tr>
#     <tr>
#       <th id="T_a3556_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a3556_row4_col0" class="data row4 col0" >0.0268</td>
#       <td id="T_a3556_row4_col1" class="data row4 col1" >0.0057</td>
#       <td id="T_a3556_row4_col2" class="data row4 col2" >0.0758</td>
#       <td id="T_a3556_row4_col3" class="data row4 col3" >0.6841</td>
#       <td id="T_a3556_row4_col4" class="data row4 col4" >0.0675</td>
#       <td id="T_a3556_row4_col5" class="data row4 col5" >0.2468</td>
#     </tr>
#     <tr>
#       <th id="T_a3556_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a
td>
#     </tr>
#     <tr>
#       <th id="T_e55ed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e55ed_row8_col0" class="data row8 col0" >0.0510</td>
#       <td id="T_e55ed_row8_col1" class="data row8 col1" >0.0060</td>
#       <td id="T_e55ed_row8_col2" class="data row8 col2" >0.0773</td>
#       <td id="T_e55ed_row8_col3" class="data row8 col3" >0.6629</td>
#       <td id="T_e55ed_row8_col4" class="data row8 col4" >0.0691</td>
#       <td id="T_e55ed_row8_col5" class="data row8 col5" >0.5222</td>
#     </tr>
#     <tr>
#       <th id="T_e55ed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e55ed_row9_col0" class="data row9 col0" >0.0519</td>
#       <td id="T_e55ed_row9_col1" class="data row9 col1" >0.0087</td>
#       <td id="T_e55ed_row9_col2" class="data row9 col2" >0.0931</td>
#       <td id="T_e55ed_row9_col3" class="data row9 col3" >0.4653</td>
#       <td id="T_e55ed_row9_col4" class="data row9 col4" >0.0790</td>
#       <td id="T_e55ed_row9_col5" class="data row9 col5" >0.5242</td>
#     </tr>
#     <tr>
#       <th id="T_e55ed_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e55ed_row10_col0" class="data row10 col0" >0.0502</td>
#       <td id="T_e55ed_row10_col1" class="data row10 col1" >0.0069</td>
#       <td id="T_e55ed_row10_col2" class="data row10 col2" >0.0828</td>
#       <td id="T_e55ed_row10_col3" class="data row10 col3" >0.5812</td>
#       <td id="T_e55ed_row10_col4" class="data row10 col4" >0.0724</td>
#       <td id="T_e55ed_row10_col5" class="data row10 col5" >0.5173</td>
#     </tr>
#     <tr>
#       <th id="T_e55ed_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e55ed_row11_col0" class="data row11 col0" >0.0024</td>
#       <td id="T_e55ed_row11_col1" class="data row11 col1" >0.0009</td>
#       <td id="T_e55ed_row11_col2" class="data row11 col2" >0.0053</td>
#       <td id="T_e55ed_row11_col3" class="data row11 col3" >0.0699</td>
#       <td id="T_e55ed_row11_col4" class="data row11 col4" >0.0040</td>
#       <td id="T_e55ed_row11_col5" class="data row11 col5" >0.0229</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# # Vykrelsení výsledků

# %%
zbytek = dataframe[8762:] #zbytek se musí definovat až tady pro opakovatelnost spuštění této buňky
cor_diff = np.cumsum(dataframe['corrosion_diff'])

# Inicializace grafu
fig = go.Figure()


# První graf: původní časová řada
fig.add_trace(
    go.Scatter(
        x=datetime,
        y=cor_diff,
        mode='lines',
        name = 'Původní časová řada'
    )
)

zbytek = zbytek.drop(columns=['corrosion_diff'])
predictions = exp.predict_model(best_model, data=zbytek)
predictions = predictions.rename(columns={'prediction_label': 'corrosion_diff'})

# posunutí odhadů pro porovnání s původní časovou řadou
pred_shifted = predictions['corrosion_diff']
pred_shifted[8762] += cor_diff[8761]  # přidání poslední hodnoty původní řady

# Druhý graf: predikovaná časová řada
fig.add_trace(
    go.Scatter(
        x=datetime[8762:],
        y=np.cumsum(pred_shifted),
        mode='lines',
        name = 'Extra trees regressor'
    )
)


# Update rozložení grafu
fig.update_layout(
    legend=dict(
        bgcolor='rgba(0,0,0,0)',  # Set background to transparent
        x=0,
        y=1,
        xanchor='left',
        yanchor='top'),
    xaxis_title='Datum',
    yaxis_title='Míra koroze',
    
)


fig.show()

# %%
# exp.save_model(best_model, 'corrosion_regressor_model')
# exp.save_experiment('corrosion_regression_experiment')
# exp.create_api(best_model, 'corrosion_regressor_api')
# exp.create_docker('corrosion_regressor_api')
# Out:
# Transformation Pipeline and Model Successfully Saved
# API successfully created. This function only creates a POST API, it doesn't run it automatically. To run your API, please run this command --> !python corrosion_regressor_api.py
# Writing requirements.txt
# Writing Dockerfile
# Dockerfile and requirements.txt successfully created.
#     To build image you have to run --> !docker image build -f "Dockerfile" -t IMAGE_NAME:IMAGE_TAG .
